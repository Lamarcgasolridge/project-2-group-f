# %%
import pandas as pd

# %%
data_population= pd.read_csv("Resources/population_total_long.csv")

# %%
data_population.head(100)
# Out:
#    Country Name  Year     Count
# 0         Aruba  1960     54211
# 1   Afghanistan  1960   8996973
# 2        Angola  1960   5454933
# 3       Albania  1960   1608800
# 4       Andorra  1960     13411
# ..          ...   ...       ...
# 95       Israel  1960   2114020
# 96        Italy  1960  50199700
# 97      Jamaica  1960   1628520
# 98       Jordan  1960    933102
# 99        Japan  1960  92500572
#
# [100 rows x 3 columns]

# %%
data_population.tail(100)
# Out:
#                    Country Name  Year     Count
# 12495          Macao SAR, China  2017    622585
# 12496  St. Martin (French part)  2017     36560
# 12497                   Morocco  2017  35581294
# 12498                    Monaco  2017     38392
# 12499                   Moldova  2017   3549196
# ...                         ...   ...       ...
# 12590                    Kosovo  2017   1830700
# 12591               Yemen, Rep.  2017  27834821
# 12592              South Africa  2017  57000451
# 12593                    Zambia  2017  16853688
# 12594                  Zimbabwe  2017  14236745
#
# [100 rows x 3 columns]

# %%
data_population.head(20)
# Out:
#             Country Name  Year     Count
# 0                  Aruba  1960     54211
# 1            Afghanistan  1960   8996973
# 2                 Angola  1960   5454933
# 3                Albania  1960   1608800
# 4                Andorra  1960     13411
# 5   United Arab Emirates  1960     92418
# 6              Argentina  1960  20481779
# 7                Armenia  1960   1874121
# 8         American Samoa  1960     20123
# 9    Antigua and Barbuda  1960     54131
# 10             Australia  1960  10276477
# 11               Austria  1960   7047539
# 12            Azerbaijan  1960   3895397
# 13               Burundi  1960   2797932
# 14               Belgium  1960   9153489
# 15                 Benin  1960   2431622
# 16          Burkina Faso  1960   4829288
# 17            Bangladesh  1960  48013504
# 18              Bulgaria  1960   7867374
# 19               Bahrain  1960    162427

# %%
data_population.tail(20)
# Out:
#                          Country Name  Year      Count
# 12575                          Turkey  2017   81101892
# 12576                          Tuvalu  2017      11370
# 12577                        Tanzania  2017   54663906
# 12578                          Uganda  2017   41162465
# 12579                         Ukraine  2017   44831135
# 12580                         Uruguay  2017    3436646
# 12581                   United States  2017  325147121
# 12582                      Uzbekistan  2017   32388600
# 12583  St. Vincent and the Grenadines  2017     109827
# 12584                   Venezuela, RB  2017   29390409
# 12585          British Virgin Islands  2017      29577
# 12586           Virgin Islands (U.S.)  2017     107268
# 12587                         Vietnam  2017   94596642
# 12588                         Vanuatu  2017     285510
# 12589                           Samoa  2017     195352
# 12590                          Kosovo  2017    1830700
# ...

# %%
data_population.plot()
# Out:
# <AxesSubplot:>

# %%
data_population.loc[[0, 1]]
# Out:
#   Country Name  Year    Count
# 0        Aruba  1960    54211
# 1  Afghanistan  1960  8996973

# %%
data_population.loc[[20, 30]]
# Out:
#     Country Name  Year   Count
# 20  Bahamas, The  1960  109534
# 30      Botswana  1960  502745

# %%
for col in data_population:
    print(col)
# Out:
# Country Name
# Year
# Count

# %%
for row in data_population:
    print(row)
# Out:
# Country Name
# Year
# Count

# %%
list(data_population)
# Out:
# ['Country Name', 'Year', 'Count']

# %%
list(data_population.values)
# Out:
# [array(['Aruba', 1960, 54211], dtype=object),
#  array(['Afghanistan', 1960, 8996973], dtype=object),
#  array(['Angola', 1960, 5454933], dtype=object),
#  array(['Albania', 1960, 1608800], dtype=object),
#  array(['Andorra', 1960, 13411], dtype=object),
#  array(['United Arab Emirates', 1960, 92418], dtype=object),
#  array(['Argentina', 1960, 20481779], dtype=object),
#  array(['Armenia', 1960, 1874121], dtype=object),
#  array(['American Samoa', 1960, 20123], dtype=object),
#  array(['Antigua and Barbuda', 1960, 54131], dtype=object),
#  array(['Australia', 1960, 10276477], dtype=object),
#  array(['Austria', 1960, 7047539], dtype=object),
#  array(['Azerbaijan', 1960, 3895397], dtype=object),
#  array(['Burundi', 1960, 2797932], dtype=object),
#  array(['Belgium', 1960, 9153489], dtype=object),
#  array(['Benin', 1960, 2431622], dtype=object),
#  array(['Burkina Faso', 1960, 4829288], dtype=object),
#  array(['Bangladesh', 1960, 48013504], dtype=object),
# ...

# %%
data_population= pd.read_csv("Resources/pop_worldometer_data.csv")

# %%
data_population.head()
# Out:
#   Country (or dependency)  Population (2020)  Yearly Change %  Net Change  \
# 0                   China         1439323776             0.39     5540090
# 1                   India         1380004385             0.99    13586631
# 2           United States          331002651             0.59     1937734
# 3               Indonesia          273523615             1.07     2898047
# 4                Pakistan          220892340             2.00     4327022
#
#    Density (P/Km²)  Land Area (Km²)  Migrants (net)  Fert. Rate  Med. Age  \
# 0            153.0        9388211.0       -348399.0         1.7      38.0
# 1            464.0        2973190.0       -532687.0         2.2      28.0
# 2             36.0        9147420.0        954806.0         1.8      38.0
# 3            151.0        1811570.0        -98955.0         2.3      30.0
# 4            287.0         770880.0       -233379.0         3.6      23.0
#
#    Urban Pop %  World Share %
# 0         61.0          18.47
# ...

# %%
data_population.tail(20)
# Out:
#      Country (or dependency)  Population (2020)  Yearly Change %  Net Change  \
# 215             Saint Martin              38666             1.75         664
# 216            Liechtenstein              38128             0.29         109
# 217               San Marino              33931             0.21          71
# 218                Gibraltar              33691              NaN         -10
# 219   British Virgin Islands              30231             0.67         201
# 220    Caribbean Netherlands              26223             0.94         244
# 221                    Palau              18094             0.48          86
# 222             Cook Islands              17564             0.09          16
# 223                 Anguilla              15003             0.90         134
# 224                   Tuvalu              11792             1.25         146
# 225          Wallis & Futuna              11239              NaN        -193
# ...

# %%
data_population.mean()
# Out:
# Population (2020)    3.316936e+07
# Yearly Change %      1.330146e+00
# Net Change           3.460878e+05
# Density (P/Km²)      4.757702e+02
# Land Area (Km²)      5.535918e+05
# Migrants (net)       6.283582e+00
# Fert. Rate           2.693035e+00
# Med. Age             3.060697e+01
# Urban Pop %          5.923423e+01
# World Share %        4.254468e-01
# dtype: float64

# %%
gh_inventory=pd.read_csv("Resources/greenhouse_gas_inventory_data_data.csv")

# %%
len(gh_inventory['country_or_area'].unique())
# Out:
# 43

# %%
gh_inventory.head(100)
# Out:
#    country_or_area  year          value  \
# 0        Australia  2014  393126.946994
# 1        Australia  2013  396913.936530
# 2        Australia  2012  406462.847704
# 3        Australia  2011  403705.528314
# 4        Australia  2010  406200.993184
# ..             ...   ...            ...
# 95         Belgium  1994  124426.885710
# 96         Belgium  1993  121156.964955
# 97         Belgium  1992  122217.919518
# 98         Belgium  1991  123130.652897
# 99         Belgium  1990  119982.503419
#
#                                              category
# 0   carbon_dioxide_co2_emissions_without_land_use_...
# 1   carbon_dioxide_co2_emissions_without_land_use_...
# 2   carbon_dioxide_co2_emissions_without_land_use_...
# 3   carbon_dioxide_co2_emissions_without_land_use_...
# 4   carbon_dioxide_co2_emissions_without_land_use_...
# ..                                                ...
# 95  carbon_dioxide_co2_emissions_without_land_use_...
# ...

# %%
country_data=pd.read_csv("Resources/pop_worldometer_data.csv")

# %%
country_data.head()
# Out:
#   Country (or dependency)  Population (2020)  Yearly Change %  Net Change  \
# 0                   China         1439323776             0.39     5540090
# 1                   India         1380004385             0.99    13586631
# 2           United States          331002651             0.59     1937734
# 3               Indonesia          273523615             1.07     2898047
# 4                Pakistan          220892340             2.00     4327022
#
#    Density (P/Km²)  Land Area (Km²)  Migrants (net)  Fert. Rate  Med. Age  \
# 0            153.0        9388211.0       -348399.0         1.7      38.0
# 1            464.0        2973190.0       -532687.0         2.2      28.0
# 2             36.0        9147420.0        954806.0         1.8      38.0
# 3            151.0        1811570.0        -98955.0         2.3      30.0
# 4            287.0         770880.0       -233379.0         3.6      23.0
#
#    Urban Pop %  World Share %
# 0         61.0          18.47
# ...

# %%
data_population["Yearly Change %"].mean()
# Out:
# 1.3301456310679605

# %%
data_population["Land Area (Km²)"].mean()
# Out:
# 553591.8425531915

# %%
data_population["Net Change"].mean()
# Out:
# 346087.8255319149
