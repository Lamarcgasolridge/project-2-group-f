# %% [markdown]
# # Import files

# %%
import csv 
import pandas as pd
import numpy as np

# %%
file_1 = "Resources/pop_worldometer_data.csv"
pop_world_csv = pd.read_csv(file_1)
pop_world_csv
# Out:
#     Country (or dependency)  Population (2020)  Yearly Change %  Net Change  \
# 0                     China         1439323776             0.39     5540090
# 1                     India         1380004385             0.99    13586631
# 2             United States          331002651             0.59     1937734
# 3                 Indonesia          273523615             1.07     2898047
# 4                  Pakistan          220892340             2.00     4327022
# ..                      ...                ...              ...         ...
# 230              Montserrat               4992             0.06           3
# 231        Falkland Islands               3480             3.05         103
# 232                    Niue               1626             0.68          11
# 233                 Tokelau               1357             1.27          17
# 234                Holy See                801             0.25           2
#
# ...

# %%
file_2 = "Resources/population_above_age_65_percentage_long.csv"
pop_65_csv = pd.read_csv(file_2)
pop_65 = pop_65_csv.rename(columns={"Count": "Count >65"})
pop_65
# Out:
#                Country Name  Year  Count >65
# 0                     Aruba  1960          2
# 1               Afghanistan  1960          2
# 2                    Angola  1960          3
# 3                   Albania  1960          5
# 4      United Arab Emirates  1960          3
# ...                     ...   ...        ...
# 11297                 Samoa  2017          4
# 11298           Yemen, Rep.  2017          2
# 11299          South Africa  2017          5
# 11300                Zambia  2017          2
# 11301              Zimbabwe  2017          2
#
# [11302 rows x 3 columns]

# %%
file_3 = "Resources/population_below_age_14_percentage_long.csv"
pop_14_csv = pd.read_csv(file_3)
pop_14 = pop_14_csv.rename(columns={"Count": "Count <14"})
pop_14
# Out:
#                Country Name  Year  Count <14
# 0                     Aruba  1960         43
# 1               Afghanistan  1960         42
# 2                    Angola  1960         42
# 3                   Albania  1960         40
# 4      United Arab Emirates  1960         44
# ...                     ...   ...        ...
# 11297                 Samoa  2017         38
# 11298           Yemen, Rep.  2017         40
# 11299          South Africa  2017         29
# 11300                Zambia  2017         45
# 11301              Zimbabwe  2017         42
#
# [11302 rows x 3 columns]

# %%
file_3 = "Resources/population_density_long.csv"
pop_density_csv = pd.read_csv(file_3)
pop_density = pop_density_csv.rename(columns={"Count": "Density Count"})
pop_density
# Out:
#        Country Name  Year  Density Count
# 0             Aruba  1961            307
# 1       Afghanistan  1961             14
# 2            Angola  1961              4
# 3           Albania  1961             60
# 4           Andorra  1961             30
# ...             ...   ...            ...
# 12062        Kosovo  2017            168
# 12063   Yemen, Rep.  2017             52
# 12064  South Africa  2017             46
# 12065        Zambia  2017             22
# 12066      Zimbabwe  2017             36
#
# [12067 rows x 3 columns]

# %%
file_4 = "Resources/population_female_percentage_long.csv"
pop_female_csv = pd.read_csv(file_4)
pop_female = pop_female_csv.rename(columns={"Count": "Female Count"})
pop_female
# Out:
#                Country Name  Year  Female Count
# 0                     Aruba  1960            50
# 1               Afghanistan  1960            48
# 2                    Angola  1960            49
# 3                   Albania  1960            48
# 4      United Arab Emirates  1960            49
# ...                     ...   ...           ...
# 11297                 Samoa  2017            48
# 11298           Yemen, Rep.  2017            49
# 11299          South Africa  2017            50
# 11300                Zambia  2017            50
# 11301              Zimbabwe  2017            52
#
# [11302 rows x 3 columns]

# %%
file_5 = "Resources/population_total_long.csv"
pop_total_csv = pd.read_csv(file_5)
pop_total = pop_total_csv.rename(columns={"Count": "Total Counts"})
pop_total
# Out:
#        Country Name  Year  Total Counts
# 0             Aruba  1960         54211
# 1       Afghanistan  1960       8996973
# 2            Angola  1960       5454933
# 3           Albania  1960       1608800
# 4           Andorra  1960         13411
# ...             ...   ...           ...
# 12590        Kosovo  2017       1830700
# 12591   Yemen, Rep.  2017      27834821
# 12592  South Africa  2017      57000451
# 12593        Zambia  2017      16853688
# 12594      Zimbabwe  2017      14236745
#
# [12595 rows x 3 columns]

# %%
file_6 = "Resources/WorldPopulation.csv"
wp_csv = pd.read_csv(file_6)
wp_csv
# Out:
#     Year  Population  ChangePerc  NetChange  Density       Urban  UrbanPerc
# 0   2020  7794798739        1.05   81330639       52  4378993944         56
# 1   2019  7713468100        1.08   82377060       52  4299438618         56
# 2   2018  7631091040        1.10   83232115       51  4219817318         55
# 3   2017  7547858925        1.12   83836876       51  4140188594         55
# 4   2016  7464022049        1.14   84224910       50  4060652683         54
# ..   ...         ...         ...        ...      ...         ...        ...
# 65  1955  2773019936        1.77   48173195       19   877008842         32
# 66  1954  2724846741        1.76   47237781       18   850179106         31
# 67  1953  2677608960        1.78   46747398       18   824289989         31
# 68  1952  2630861562        1.81   46827301       18   799282533         30
# 69  1951  2584034261        1.88   47603112       17   775067697         30
#
# [70 rows x 7 columns]

# %%
file_7 = "Resources/region_codes.csv"
region_csv = pd.read_csv(file_7)
region_csv
# Out:
#                   name alpha-2 alpha-3  country-code     iso_3166-2   region  \
# 0          Afghanistan      AF     AFG             4  ISO 3166-2:AF     Asia
# 1        Åland Islands      AX     ALA           248  ISO 3166-2:AX   Europe
# 2              Albania      AL     ALB             8  ISO 3166-2:AL   Europe
# 3              Algeria      DZ     DZA            12  ISO 3166-2:DZ   Africa
# 4       American Samoa      AS     ASM            16  ISO 3166-2:AS  Oceania
# ..                 ...     ...     ...           ...            ...      ...
# 244  Wallis and Futuna      WF     WLF           876  ISO 3166-2:WF  Oceania
# 245     Western Sahara      EH     ESH           732  ISO 3166-2:EH   Africa
# 246              Yemen      YE     YEM           887  ISO 3166-2:YE     Asia
# 247             Zambia      ZM     ZMB           894  ISO 3166-2:ZM   Africa
# 248           Zimbabwe      ZW     ZWE           716  ISO 3166-2:ZW   Africa
#
# ...

# %%
file_8 = "Resources/greenhouse_gas_inventory_data_data.csv"
greenhouse_gas = pd.read_csv(file_8)
greenhouse_gas_1 = greenhouse_gas.rename(columns={"country_or_area": "Country Name",
                                                  "year": "Year",
                                                  "value": "Greenhouse Gas Value",
                                                  "category": "Greenhouse Category"
                                                 })
greenhouse_gas_1
# Out:
#                   Country Name  Year  Greenhouse Gas Value  \
# 0                    Australia  2014         393126.946994
# 1                    Australia  2013         396913.936530
# 2                    Australia  2012         406462.847704
# 3                    Australia  2011         403705.528314
# 4                    Australia  2010         406200.993184
# ...                        ...   ...                   ...
# 8401  United States of America  1994            593.222570
# 8402  United States of America  1993            586.939752
# 8403  United States of America  1992            574.414624
# 8404  United States of America  1991            566.900968
# 8405  United States of America  1990            293.205663
#
#                                     Greenhouse Category
# 0     carbon_dioxide_co2_emissions_without_land_use_...
# 1     carbon_dioxide_co2_emissions_without_land_use_...
# 2     carbon_dioxide_co2_emissions_without_land_use_...
# ...

# %% [markdown]
# # Merge data frames

# %%
pop_merge = pd.concat([pop_total_csv, pop_density_csv, pop_female_csv], axis=1)
pop_merge.dropna()
# Out:
#       Country Name  Year     Count Country Name    Year  Count  \
# 0            Aruba  1960     54211        Aruba  1961.0  307.0
# 1      Afghanistan  1960   8996973  Afghanistan  1961.0   14.0
# 2           Angola  1960   5454933       Angola  1961.0    4.0
# 3          Albania  1960   1608800      Albania  1961.0   60.0
# 4          Andorra  1960     13411      Andorra  1961.0   30.0
# ...            ...   ...       ...          ...     ...    ...
# 11297    Australia  2012  22733465       Israel  2014.0  379.0
# 11298      Austria  2012   8429991        Italy  2014.0  206.0
# 11299   Azerbaijan  2012   9295784      Jamaica  2014.0  265.0
# 11300      Burundi  2012   9245988       Jordan  2014.0  100.0
# 11301      Belgium  2012  11106932        Japan  2014.0  349.0
#
#                Country Name    Year  Count
# 0                     Aruba  1960.0   50.0
# 1               Afghanistan  1960.0   48.0
# 2                    Angola  1960.0   49.0
# ...

# %%
pop_merge_1 = pd.concat([pop_65, pop_14, pop_density, pop_female, pop_total], axis=1)
# pop_merge_1.dropna().drop_duplicates()
df = pop_merge_1.loc[:,~pop_merge_1.columns.duplicated()]
df.dropna()
# Out:
#                Country Name    Year  Count >65  Count <14  Density Count  \
# 0                     Aruba  1960.0        2.0       43.0          307.0
# 1               Afghanistan  1960.0        2.0       42.0           14.0
# 2                    Angola  1960.0        3.0       42.0            4.0
# 3                   Albania  1960.0        5.0       40.0           60.0
# 4      United Arab Emirates  1960.0        3.0       44.0           30.0
# ...                     ...     ...        ...        ...            ...
# 11297                 Samoa  2017.0        4.0       38.0          379.0
# 11298           Yemen, Rep.  2017.0        2.0       40.0          206.0
# 11299          South Africa  2017.0        5.0       29.0          265.0
# 11300                Zambia  2017.0        2.0       45.0          100.0
# 11301              Zimbabwe  2017.0        2.0       42.0          349.0
#
#        Female Count  Total Counts
# 0              50.0         54211
# ...

# %%
file_9 = "Resources/pop_worldometer_data.csv"
region_csv = pd.read_csv(file_9)
region_csv = region_csv.rename(columns={"Country (or dependency)": "Total Counts"})
region_csv.dropna()
# Out:
#                  Total Counts  Population (2020)  Yearly Change %  Net Change  \
# 0                       China         1439323776             0.39     5540090
# 1                       India         1380004385             0.99    13586631
# 2               United States          331002651             0.59     1937734
# 3                   Indonesia          273523615             1.07     2898047
# 4                    Pakistan          220892340             2.00     4327022
# ..                        ...                ...              ...         ...
# 195  St. Vincent & Grenadines             110940             0.32         351
# 196                     Aruba             106766             0.43         452
# 197                     Tonga             105695             1.15        1201
# 199                Seychelles              98347             0.62         608
# 200       Antigua and Barbuda              97929             0.84         811
#
# ...

# %% [markdown]
# # Final DF for populations

# %%
pop_merge_1 = pd.concat([pop_65, pop_14, pop_density, pop_female, pop_total], axis=1)
# pop_merge_1.dropna().drop_duplicates()
df = pop_merge_1.loc[:,~pop_merge_1.columns.duplicated()]
df.dropna()
# Out:
#                Country Name    Year  Count >65  Count <14  Density Count  \
# 0                     Aruba  1960.0        2.0       43.0          307.0
# 1               Afghanistan  1960.0        2.0       42.0           14.0
# 2                    Angola  1960.0        3.0       42.0            4.0
# 3                   Albania  1960.0        5.0       40.0           60.0
# 4      United Arab Emirates  1960.0        3.0       44.0           30.0
# ...                     ...     ...        ...        ...            ...
# 11297                 Samoa  2017.0        4.0       38.0          379.0
# 11298           Yemen, Rep.  2017.0        2.0       40.0          206.0
# 11299          South Africa  2017.0        5.0       29.0          265.0
# 11300                Zambia  2017.0        2.0       45.0          100.0
# 11301              Zimbabwe  2017.0        2.0       42.0          349.0
#
#        Female Count  Total Counts
# 0              50.0         54211
# ...

# %%
df_cc = pd.concat([df, region_csv], axis=1)
df_cc.dropna()
# Out:
#              Country Name    Year  Count >65  Count <14  Density Count  \
# 0                   Aruba  1960.0        2.0       43.0          307.0
# 1             Afghanistan  1960.0        2.0       42.0           14.0
# 2                  Angola  1960.0        3.0       42.0            4.0
# 3                 Albania  1960.0        5.0       40.0           60.0
# 4    United Arab Emirates  1960.0        3.0       44.0           30.0
# ..                    ...     ...        ...        ...            ...
# 195           Afghanistan  1961.0        2.0       42.0           20.0
# 196                Angola  1961.0        3.0       42.0          210.0
# 197               Albania  1961.0        5.0       40.0            9.0
# 199             Argentina  1961.0        5.0       30.0           98.0
# 200               Armenia  1961.0        6.0       39.0          103.0
#
#      Female Count Total Counts              Total Counts  Population (2020)  \
# ...

# %%
pop_gas = pd.concat([df_cc, greenhouse_gas_1], axis=1)
pop_gas_1 = pop_gas.loc[:,~pop_gas.columns.duplicated()]
pop_gas_1.dropna()
# Out:
#              Country Name    Year  Count >65  Count <14  Density Count  \
# 0                   Aruba  1960.0        2.0       43.0          307.0
# 1             Afghanistan  1960.0        2.0       42.0           14.0
# 2                  Angola  1960.0        3.0       42.0            4.0
# 3                 Albania  1960.0        5.0       40.0           60.0
# 4    United Arab Emirates  1960.0        3.0       44.0           30.0
# ..                    ...     ...        ...        ...            ...
# 195           Afghanistan  1961.0        2.0       42.0           20.0
# 196                Angola  1961.0        3.0       42.0          210.0
# 197               Albania  1961.0        5.0       40.0            9.0
# 199             Argentina  1961.0        5.0       30.0           98.0
# 200               Armenia  1961.0        6.0       39.0          103.0
#
#      Female Count  Total Counts  Population (2020)  Yearly Change %  \
# ...
